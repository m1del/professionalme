# %%
import os
import time
import uuid
import cv2

# %%
IMAGES_PATH = os.path.join('face_data/','images')
number_images = 30

# %%
import os
os.environ['QT_QPA_PLATFORM'] = 'wayland'

# %%
# Initialize video capture on the camera with index 1
cap = cv2.VideoCapture(4)


# Check if the camera is opened successfully
if not cap.isOpened():
    print("Error: Camera not accessible")
    exit()
    
# Capture and discard the first few frames
for _ in range(10):
    cap.read()
    
# Read a frame from the camera
ret, frame = cap.read()
if ret:
    # Display the frame in a window
    cv2.imshow('Test Frame', frame)
    cv2.waitKey(0)  # Wait for a key press to close the window
else:
    print("Error: Couldn't read a frame from the camera")

# Release the camera and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Establish connection to video camera.
cap = cv2.VideoCapture(4) # pass in a camera number, might need to change it on your end

for imgnum in range(number_images):
    print('Collecting image {}'.format(imgnum))
    ret, frame = cap.read()
    imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    cv2.imshow('frame', frame)
    time.sleep(2)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
